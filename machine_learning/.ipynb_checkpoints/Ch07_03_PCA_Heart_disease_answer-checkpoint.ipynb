# %% [markdown]
# ## PCA 살펴보기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Heart Disease Data

# %%
hd = pd.read_csv("./heart.csv")
print("데이터 행:{}, 열:{}".format(hd.shape[0],hd.shape[1]))
hd.head(5)
# Out:
# 데이터 행:303, 열:14
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# 결측치 확인

# %%
print("결측치는 다행히 없는 것으로 확인")
hd.isnull().sum()
# Out:
# 결측치는 다행히 없는 것으로 확인
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# 상관계수를 구해보도록 한다
# <br>
# <br>
# **만약!! 그래프가 윗부분이 잘라질 경우**
# <br>
# Unfortunately matplotlib 3.1.1 broke seaborn heatmaps; and in general inverted axes with fixed ticks.
# This is fixed in the current development version; you may hence
#
# revert to matplotlib 3.1.0
# use matplotlib 3.1.2 or higher

# %%
corr = hd.corr()
plt.figure(figsize=(17,12))
sns.heatmap(corr, annot=True) # annot = True 를 해주어서 상관계수의 대략적인 크기 까지 나타내준다

# %% [markdown]
# 보기 불편하니 좀 더 직관적으로 들어오게 다른 plot 을 그려주어보자

# %%
hd_drop_target = hd.drop(["target"], axis = 1)
hd_target = hd["target"]

# %%
hd_drop_target.corrwith(hd_target).plot.bar(figsize = (15, 7), title = "Correlation with Target", fontsize = 15)

# %% [markdown]
# #### PCA 를 이용해 주성분 분석을 수행하여 새로운 component 를 만들도록 한다

# %%
from sklearn.decomposition import PCA
# components 수는 임의로 정한다
# 먼저 elbow point 를 알아보기 위한 plot 을 그려준 후 다시 PCA 를 설정하도록 한다
n = 5
pca = PCA(n_components=n)
pca_result = pca.fit_transform(hd_drop_target.values) # hd_drop_target.values = hd_drop_target 의 데이터 값

# %%
# explained_variance_ratio_ = 분산을 찾아줌

x = [i for i in range(1,n+1)]
plt.plot(x, pca.explained_variance_ratio_)
plt.plot(x, np.cumsum(pca.explained_variance_ratio_))
print('elbow point 는 component 가 2일때로 정함')
# Out:
# elbow point 는 component 가 2일때로 정함

# %% [markdown]
# PCA 의 Component 는 2개로 결정하였다.

# %%
# PCA 재실행
pca = PCA(n_components=2)
pca_result = pca.fit_transform(hd_drop_target.values)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.7475642 , 0.15037022])

# %%
# pca.components_ 수만큼 주성분 번호 할당
dimensions = ['Components {}'.format(i) for i in range(len(pca.components_))]
dimensions
# Out:
# ['Components 0', 'Components 1']

# %% [markdown]
# ##### DataFrame 으로 정리해보자

# %%
# 주성분 DataFrame 으로 정리
# np.round(pca.components_, 4) = 소수점 4자리까지

components = pd.DataFrame(np.round(pca.components_, 4), columns = list(hd_drop_target.keys()))
components.index = dimensions
components
# Out:
#                  age     sex      cp  trestbps    chol     fbs  restecg  \
# Components 0  0.0395 -0.0018 -0.0015    0.0476  0.9981  0.0001  -0.0016
# Components 1  0.1822  0.0008 -0.0125    0.1038 -0.0194  0.0005  -0.0012
#
#               thalach   exang  oldpeak   slope      ca    thal
# Components 0  -0.0074  0.0006   0.0013 -0.0001  0.0015  0.0012
# Components 1  -0.9772  0.0075   0.0179 -0.0104  0.0101  0.0026

# %%
# 주성분들을 plot 을 그리기 위한 fig 설정
_, ax = plt.subplots(figsize = (14,8))

# Plot 그리기
components.plot(ax = ax, kind = 'bar') # bar를 해주지 않으면 각 feature 들이 연결되어서 그려짐,bar를 해주면 히스토그램처럼 그려짐
ax.set_ylabel("Feature Weights")
ax.set_xticklabels(dimensions, rotation=0)
# Out:
# [Text(0, 0, 'Components 0'), Text(0, 0, 'Components 1')]

# %%
# PCA 주성분 분산
ratios = pca.explained_variance_ratio_
variance_ratios = pd.DataFrame(np.round(ratios, 4), columns = ['PCA 주성분 분산'])
variance_ratios.index = dimensions # dimensions => ['주성분 1', '주성분 2', '주성분 3']

variance_ratios
# Out:
#               PCA 주성분 분산
# Components 0      0.7476
# Components 1      0.1504
