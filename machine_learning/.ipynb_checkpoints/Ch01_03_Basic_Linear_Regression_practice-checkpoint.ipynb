# %% [markdown]
# > # Chapter01 - Linear Regression
# ***
#
#      - with Sin Function

# %% [markdown]
# 친숙하게 알고 있는 Sin 그래프를 이용해서 <br>
# Linear Regression 을 Scikit Learn Library 를 이용해 수행해보자

# %% [markdown]
# ### Import Library

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Prepare simple dataset

# %%
print(np.pi)
# Out:
# 3.141592653589793

# %%
# true data
N = 100

# linspace = 선형 구간 혹은 로그 구간을 지정한 구간의 수만큼 분할한다.
# 시작, 끝(포함), 갯수
# reshape = 기존 데이터는 유지하고 차원과 형상을 바꿈.
# ex) 3개의 행과 4개의 열로 구성된 배열로 재설정하고 싶으면 reshape(3, 4)
# reshape(N,1) = N개 행, 1개 열

# x 값은 0/~2*pi 이고
# y 값은 -1~1 사이의 값
# 0에서 2pi를 균등하게 100개로 분할한다
X = np.linspace(0, 2*np.pi, N)
X[:10]
# Out:
# array([0.        , 0.06346652, 0.12693304, 0.19039955, 0.25386607,
#        0.31733259, 0.38079911, 0.44426563, 0.50773215, 0.57119866])

# %%
X.reshape(N, 1)[:5]
# Out:
# array([[0.        ],
#        [0.06346652],
#        [0.12693304],
#        [0.19039955],
#        [0.25386607]])

# %%
# plot 그리기

y = np.sin(X).reshape(-1, 1)
plt.plot(X, y)
plt.scatter(X, y)

# %% [markdown]
# #### Noise 만들어주기
# - rand (0과 1사이의 난수를 발생시키는) 명령어를 사용
# - uniform variable

# %%
# ?np.random.rand

# %%
y.shape
# Out:
# (100, 1)

# %%
(0.3*np.random.rand(N, 1)).shape
# Out:
# (100, 1)

# %%
np.random.seed(1)
y += 0.3*np.random.rand(N, 1)

plt.scatter(X, y)
plt.title('sine wave noise data')
plt.show()

# %%
# 기존 그래프와 함께 plotting

y = np.sin(X).reshape(-1, 1)
plt.plot(X, y)

# add noise
np.random.seed(1)
y += 0.3*np.random.rand(N, 1)

plt.scatter(X, y)
plt.title('sine wave data')
plt.show()

# %% [markdown]
# #### Shuffle Dataset

# %%
# ?np.random.permutation
# random from 0 to 99

# %%
# shuffle data
np.random.seed(10)

# N은 100이므로 1~100까지의 수를 섞어준다 (permutation(N))
idx = np.random.permutation(N)
idx
# Out:
# array([19, 14, 43, 37, 66,  3, 79, 41, 38, 68,  2,  1, 60, 53, 95, 74, 92,
#        26, 59, 46, 90, 70, 50, 44, 76, 55, 21, 61,  6, 63, 42, 34, 84, 52,
#        35, 39, 45,  4,  5, 48, 32, 20, 83, 58, 47, 80, 17, 67, 81,  7, 87,
#        97, 98, 99, 24, 10, 96, 86, 56, 71, 23, 22, 91, 94, 18, 27, 88, 57,
#        31, 65, 12, 82, 30, 75, 25, 13, 69, 77, 85, 51, 49, 78, 72, 33, 62,
#        54, 11, 16, 36, 40,  0, 73,  8, 29, 93, 89, 28, 64, 15,  9])

# %%
X[1]
# Out:
# 0.06346651825433926

# %%
shuffle_X = X[idx]
shuffle_y = y[idx]

print(shuffle_X[:3])
print(shuffle_y[:3])
# Out:
# [1.20586385 0.88853126 2.72906028]
# [[0.99357831]
#  [0.78436274]
#  [0.63771433]]

# %% [markdown]
# ### Split train & test (3:1 의 비율)

# %% [markdown]
# 이미 데이터 섞어놔서, 3;1로 나누기만 하면 끝난다.

# %%
[1, 2, 3, 4, 5][:3]
# Out:
# [1, 2, 3]

# %%
# 3:1 의 비율로 train test 를 나눔
n = int(N*(3/4))

# train data
X_train = shuffle_X[:n]
y_train = shuffle_y[:n]

# %%
# test data
X_test = shuffle_X[n:]
y_test =shuffle_y[n:]

# %%
# plot
plt.scatter(X_train, y_train, label='train')
plt.legend()
plt.title('sine wave train data')
plt.show()

plt.scatter(X_test, y_test, label='test')
plt.legend()
plt.title('sine wave test data')
plt.show()

# %% [markdown]
# ### Perform Linear Regression
# - compute W using sklearn library

# %%
X_train.reshape(-1, 1)[:5], y_train[:5]
# Out:
# (array([[1.20586385],
#         [0.88853126],
#         [2.72906028],
#         [2.34826118],
#         [4.1887902 ]]),
#  array([[ 0.99357831],
#         [ 0.78436274],
#         [ 0.63771433],
#         [ 0.96308187],
#         [-0.66688701]]))

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_train.reshape(-1, 1), y_train)

print(reg.intercept_)
print(reg.coef_)
# Out:
# [1.02083628]
# [[-0.27359283]]

# %% [markdown]
# ### X data 을 이용해서 Prediction 을 하기 위해서는 .predict 를 이용

# %%
X_train = X_train.reshape(-1, 1)
Pred = reg.predict(X_train)

# %%
plt.figure()
plt.scatter(X_train, Pred, label='pred')
plt.scatter(X_train, y_train, label='target')
plt.legend()
plt.title('train data')
plt.show()

# %%
X_test = X_test.reshape(-1, 1)

# %%
plt.figure()
plt.scatter(X_test, reg.predict(X_test), label='pred')
plt.scatter(X_test, y_test, label='target')
plt.legend()
plt.title('test data')
plt.show()

# %% [markdown]
# ## Practice
#  - Another Dataset
#  - 임의의 function 을 지정한 후 linear regression 을 수행
#
#  $
# \begin{align}
# {y = 2x + 5}
# \end{align}
# $

# %%
X = 3 * np.random.rand(100,1) # shape => (100, 1)
y = 2*X + 5

# add_noise
y_noise = y + np.random.rand(100, 1) # noise data 를 가진 y 값

# %%
plt.scatter(X, y_noise)
plt.title('dataset plot')
plt.show()

# %%
X.shape
# Out:
# (100, 1)

# %% [markdown]
# #### 아까와 같은 방식으로 풀어보자

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X, y_noise)

print(reg.intercept_)
print(reg.coef_)
# Out:
# [5.46443632]
# [[2.027286]]

# %% [markdown]
# $$ {y = 2.027286x + 5.46443632} $$
# $$ {y = 2x + 5} $$

# %%
plt.figure()
plt.scatter(X, y_noise, label='target')
plt.scatter(X, reg.predict(X), label='pred')
plt.legend()
plt.title('train data')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# #### Anonther Dataset
#
# $
# \begin{align}
# {y = x^2 + 3x + 5}
# \end{align}
# $

# %%
np.random.rand(N,1)[:3]
# Out:
# array([[0.75472357],
#        [0.27252618],
#        [0.566517  ]])

# %%
np.random.seed(5)

N = 100
# 기존 x 범위는 0~6 사이였으나 -3 이 있으므로 -3~3 이 범위로 바뀌게 된다.
X = 6 * np.random.rand(N,1)-3 
y = X**2 + 3*X +5

# %% [markdown]
# noise 추가

# %%
y_noise = y + 3*np.random.rand(N, 1)

# %%
plt.scatter(X, y_noise)
plt.title('dataset set')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X, y_noise)

print('w0: ', reg.intercept_)
print('w1: ', reg.coef_)
# Out:
# w0:  [9.86809285]
# w1:  [[2.97610592]]

# %%
plt.figure()
plt.scatter(X, y_noise, label='target')
plt.scatter(X, reg.predict(X), label='pred')

plt.legend()
plt.title('Prediction')
plt.show()

# %% [markdown]
#  - 위의 예시에서 보듯, Sin Function 그래프를 1차원 직선으로 나타내기엔 무리가 있음
#  - X 의 feature 를 더 추가해주어서 좀 더 정확한 Linear Regression 을 수행

# %% [markdown]
# ### 좀 더 자세히 살펴보자

# %% [markdown]
# 위의 예시에서 풀어왔던 Linear Regression 의 경우
#
# $
# \begin{align}
# y_{1} = w_{1}x_{1} + w_{0}
# \end{align}
# $
#
# (여기서 $w_{1}$ 은 reg.coef_ 이고 $w_{0}$ 은 reg.intercept_ 로 구했음) <br>
# 와 같은 간단한 직선 방정식의 형태를 가정하고 풀었던 과정이었다.
# ***
# 이것은 우리가 가지고 있는 X 의 feature 가 하나 밖에 있지 않았기 때문이다.<br>
# 하지만 X 의 feature 를 제곱, 세제곱의 형태로 임의로 늘려준다면 방정식은 1차원의 직선이 아닌, 아래와 같이 고차원의 식으로 변할 수 있다.
#
# $
# \begin{align}
# y_{1} = w_{n}x_{1}^n + w_{n-1}x_{1}^{n-1} + ... + w_{2}x_{1}^2 + w_{1}x_{1}^1 + w_{0}
# \end{align}
# $
#
# 여기서<br>
#
# ${\phi}$ function 을 새로 정의하고 이것이 다음을 나타 낼 때,
#
# $
# \begin{align}
# {\phi}_{n}(x) = x^n
# \end{align}
# $
#
# 주어진 식은 다음과 같이 다시 쓸 수 있다.<br>
#
# $
# \begin{align}
# y_{1} = w_{n}{\phi}_{n}(x_{1}) + w_{n-1}{\phi}_{n-1}(x_{1}) + ... + w_{2}{\phi}_{2}(x_{1}) + w_{1}{\phi}_{1}(x_{1}) + w_{0}{\phi}_{0}(x_{1})
# \end{align}
# $
# ***
# 즉, 기존의 X 를 제곱, 세제곱의 형태를 만들어서 feature 를 추가해준다면, 좀 더 정확한 Model 을 얻게 될 것이다.

# %% [markdown]
# ****
# #### Library 를 이용해서 feature 를 추가해보자.

# %% [markdown]
# Feature 를 추가 할 때는 PolynomialFeatures 를 사용<br>
# 제곱, 세제곱 등의 계산이 가능

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
# transform from (x1, x2) to (1, x1, x2, x1^2, x1*x2, x2^2) ## default
# transform from (x1, x2) to (x1, x2, x1^2, x1*x2, x2^2) ## include_bias = False

# True/False 1 차이
polynomial = PolynomialFeatures(degree=2, include_bias=False)
new_feature = polynomial.fit_transform(X)

# %%
new_feature[:5]
# Out:
# array([[-1.66804097e+00,  2.78236069e+00],
#        [ 2.22439384e+00,  4.94792794e+00],
#        [-1.75968507e+00,  3.09649154e+00],
#        [ 2.51166545e+00,  6.30846332e+00],
#        [-6.95328672e-02,  4.83481963e-03]])

# %%
print("기존의 x[0]:",X[0])
print("Feature가 추가된 x[0]:", new_feature[0])
# Out:
# 기존의 x[0]: [-1.66804097]
# Feature가 추가된 x[0]: [-1.66804097  2.78236069]

# %%
print(-1.66804097*-1.66804097)
# Out:
# 2.782360677598541

# %% [markdown]
# ##### Feature 를 추가한 상태에서 LinearRegression 을 다시 사용

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(new_feature, y_noise)

print('w0: ', reg.intercept_)
print('w1: ', reg.coef_)
# Out:
# w0:  [6.82439098]
# w1:  [[3.02103818 0.92278965]]

# %% [markdown]
# $$ {y = x^2 + 3x + 5} $$
# $$ {y = 0.92x^2 + 3.02x + 6.82} $$

# %%
plt.figure()
plt.scatter(X, y_noise, label='target')
plt.scatter(X, reg.predict(new_feature), label='pred')

plt.legend()
plt.title('test data')
plt.show()

# %% [markdown]
# # Practice1

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# x 의 범위는 -2~2 <br>
# $$ {y = 3x^3 + 2x^2 + 7x + 5} $$

# %%
np.random.seed(10)

N = 100
X = 4 * np.random.rand(N,1)-2 # -2~2 로 범위를 만들기 위해 -2 를 끝에 붙임
y = 3*X**3 + 2*X**2 + 7*X + 5

y_noise = y + 10*np.random.rand(N, 1)

# %%
plt.scatter(X, y_noise)
plt.title('dataset set')
plt.show()

# %%
polynomial = PolynomialFeatures(degree=3, include_bias=False)
new_feature_three = polynomial.fit_transform(X)

print("기존의 x[0]:",X[0])
print("Feature가 추가된 x[0]:", new_feature_three[0])
# Out:
# 기존의 x[0]: [1.08528257]
# Feature가 추가된 x[0]: [1.08528257 1.17783826 1.27828734]

# %%
reg = LinearRegression()
reg.fit(new_feature_three, y_noise)

print('w0: ', reg.intercept_)
print('w1: ', reg.coef_)
# Out:
# w0:  [9.18157997]
# w1:  [[6.35064075 2.3300474  3.20666863]]

# %%
plt.figure()
plt.scatter(X, y_noise, label='target')
plt.scatter(X, reg.predict(new_feature_three), label='pred')

plt.legend()
plt.title('PolyNomial')
plt.show()

# %% [markdown]
# $$ {y = 3x^3 + 2x^2 + 7x + 1} $$
# $$ {y = 3.20x^3 + 2.33x^2 + 6.35x + 9.18} $$

# %% [markdown]
# # Practice 2

# %% [markdown]
# ### 앞서 했던 sin 함수를 1차 그래프가 아닌 다차원 그래프로 정확한 예측을 해보자

# %%
N = 100

X = np.linspace(0, 2*np.pi, N).reshape(N, 1)
Y = np.sin(X) + 0.3*np.random.rand(N, 1)

# %%
X.shape, Y.shape
# Out:
# ((100, 1), (100, 1))

# %%
plt.scatter(X, Y)

# %%
from sklearn.preprocessing import PolynomialFeatures

polynomial = PolynomialFeatures(degree = 3, include_bias = False)
sin_new_feature = polynomial.fit_transform(X)

# %%
print("기존의 x[0]:",X[1])
print("Feature가 추가된 x[0]:", sin_new_feature[1])
# Out:
# 기존의 x[0]: [0.06346652]
# Feature가 추가된 x[0]: [0.06346652 0.004028   0.00025564]

# %%
sin_new_feature[:5]
# Out:
# array([[0.        , 0.        , 0.        ],
#        [0.06346652, 0.004028  , 0.00025564],
#        [0.12693304, 0.016112  , 0.00204514],
#        [0.19039955, 0.03625199, 0.00690236],
#        [0.25386607, 0.06444798, 0.01636116]])

# %%
plt.figure()
plt.scatter(sin_new_feature[:, 0], Y)

plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Shuffle & Split train, test

# %%
# shuffle data
idx = np.random.permutation(100)

shuffle_X = sin_new_feature[idx]
shuffle_y = Y[idx]

print(shuffle_X[:3])
print(shuffle_y[:3])
# Out:
# [[  6.15625227  37.89944202 233.31852599]
#  [  4.82345539  23.26572187 112.22117151]
#  [  3.8079911   14.50079618  55.21890273]]
# [[-6.27388585e-04]
#  [-7.46618015e-01]
#  [-4.75509841e-01]]

# %%
plt.figure()
plt.scatter(shuffle_X[:,0], shuffle_y)

plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
n = int(N * (3/4))

# train data
X_train = shuffle_X[:n]
y_train = shuffle_y[:n]

# test data
X_test = shuffle_X[n:]
y_test = shuffle_y[n:]

# %%
plt.figure()
plt.scatter(X_train[:, 0], y_train)

plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Perform Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)

print('w0: ', reg.intercept_)
print('w1: ', reg.coef_)
# Out:
# w0:  [-0.19986411]
# w1:  [[ 2.07096479 -0.93131857  0.09796685]]

# %% [markdown]
# ### Plotting

# %%
Pred = reg.predict(X_train)

# %%
Pred[:5]
# Out:
# array([[ 0.11054487],
#        [-0.8845018 ],
#        [-0.40888735],
#        [-0.66691239],
#        [ 0.95235989]])

# %%
X_train[:, 0]
# Out:
# array([6.15625227, 4.82345539, 3.8079911 , 5.52158709, 2.0943951 ,
#        2.7925268 , 3.23679243, 2.47519421, 3.61759154, 6.02931923,
#        1.14239733, 1.26933037, 3.55412502, 6.28318531, 5.64852012,
#        2.72906028, 2.28479466, 2.15786162, 3.93492413, 1.45972992,
#        5.39465405, 3.36372547, 5.07732146, 5.58505361, 0.50773215,
#        4.37918976, 0.82506474, 1.96746207, 3.10985939, 3.30025895,
#        1.84052903, 3.87145761, 5.71198664, 2.53866073, 0.95199777,
#        0.6981317 , 1.77706251, 3.74452458, 6.09278575, 3.68105806,
#        4.95038842, 1.01546429, 4.88692191, 1.33279688, 3.42719199,
#        0.88853126, 0.76159822, 5.01385494, 4.1887902 , 4.12532369,
#        4.25225672, 1.07893081, 3.17332591, 0.57119866, 3.4906585 ,
#        5.83891968, 2.22132814, 2.98292636, 0.19039955, 2.85599332,
#        0.31733259, 2.34826118, 0.44426563, 1.71359599, 1.58666296,
#        2.41172769, 4.31572324, 5.96585272, 6.21971879, 3.99839065,
#        2.03092858, 2.91945984, 5.26772102, 0.63466518, 1.3962634 ])

# %%
plt.figure()
plt.scatter(X_train[:, 0], Pred, label="prediction")
plt.scatter(X_train[:, 0], y_train, label="Original")



plt.legend()
plt.title('train data')
plt.show()

# %% [markdown]
# ### Test data 로 plot

# %%
test_Pred = reg.predict(X_test)

# %%
plt.scatter(X_test[:, 0], test_Pred, label="Prediction")
plt.scatter(X_test[:, 0], y_test, label="Original")

plt.legend()
plt.title('test data')
plt.show()

# %% [markdown]
# ### Train, Test data 로 plot

# %%
X_all = shuffle_X[:]
y_all = shuffle_y[:]

all_Pred = reg.predict(X_all)

# %%
plt.figure()
plt.scatter(X_all[:,0], all_Pred, label='pred')
plt.scatter(X_all[:,0], y_all, label='target')
plt.legend()
plt.title('all data')
plt.show()
