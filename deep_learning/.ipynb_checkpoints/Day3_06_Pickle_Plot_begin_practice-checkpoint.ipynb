# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("./pickle/SGD.pickle", 'rb') as f:
    SGD = pickle.load(f)

# %%
len(SGD)
# Out:
# 900

# %%
SGD
# Out:
# [tensor(14.5651, requires_grad=True),
#  tensor(73.5663, requires_grad=True),
#  tensor(323.1079, requires_grad=True),
#  tensor(148.2604, requires_grad=True),
#  tensor(66.6861, requires_grad=True),
#  tensor(283.4831, requires_grad=True),
#  tensor(13.6886, requires_grad=True),
#  tensor(35.8386, requires_grad=True),
#  tensor(9.0690, requires_grad=True),
#  tensor(129.6212, requires_grad=True),
#  tensor(11.6082, requires_grad=True),
#  tensor(9.6957, requires_grad=True),
#  tensor(4.8658, requires_grad=True),
#  tensor(2.7146, requires_grad=True),
#  tensor(2.3035, requires_grad=True),
#  tensor(2.2313, requires_grad=True),
#  tensor(2.1982, requires_grad=True),
#  tensor(2.0863, requires_grad=True),
#  tensor(2.1427, requires_grad=True),
#  tensor(2.1746, requires_grad=True),
#  tensor(2.0608, requires_grad=True),
#  tensor(2.0758, requires_grad=True),
#  tensor(2.0257, requires_grad=True),
#  tensor(2.1421, requires_grad=True),
#  tensor(2.0575, requires_grad=True),
# ...

# %%
with open('./pickle/ADAM.pickle', 'rb') as f:
    ADAM = pickle.load(f)
    print(len(ADAM))
# Out:
# 900

# %%
with open('./pickle/Dropout.pickle', 'rb') as f:
    Dropout = pickle.load(f)
    print(len(Dropout))
# Out:
# 900

# %%
with open('./pickle/BatchNorm.pickle', 'rb') as f:
    BatchNorm = pickle.load(f)
    print(len(BatchNorm))
# Out:
# 900

# %%
plt.figure(figsize=(15, 10))

plt.plot(np.array(SGD[17:]), 'g', label='SGD')
plt.plot(np.array(ADAM[17:]), 'r', label='ADAM')
plt.plot(np.array(Dropout[17:]), 'y', label='Dropout')
plt.plot(np.array(BatchNorm[17:]), 'k', label='BatchNorm')

plt.legend()
plt.grid('on')
plt.show()
