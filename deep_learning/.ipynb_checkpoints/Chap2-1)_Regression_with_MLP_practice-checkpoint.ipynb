# %% [markdown]
# # MLP(Multi Layer Perceptron) - Regression

# %%
import torch
import torch.nn as nn
import torch.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.utils.data as data_utils

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

# %% [markdown]
# ### 1) Data

# %%
#데이터 판다스로 불러오기
df_raw = pd.read_csv("./data/BostonHousing.csv") #csv(comma-separated values)파일 가져오기(디럭토리 주소입력)
print(type(df_raw))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df_raw.shape) # Dataset의 크기 확인
df_raw
# Out:
# (506, 14)
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
# X값 coulumn
x = df_raw.drop(["medv"], axis=1) #Target 값에 해당하는 집값('medv') 열을 삭제

# y값 column
y = df_raw["medv"]

print(x.shape)
print(y.shape)
print(type(y))
# Out:
# (506, 13)
# (506,)
# <class 'pandas.core.series.Series'>

# %%
#학습데이터와 테스트데이터를 일정비율로 나누기
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=1234)

#학습 데이터
print("x_train의 크기: ",x_train.shape)
print("y_train의 크기: ",y_train.shape,'\n')

#테스트 데이터 
print("x_test의 크기: ",x_test.shape)
print("y_test의 크기: ",y_test.shape)
print(type(y_train))
# Out:
# x_train의 크기:  (354, 13)
# y_train의 크기:  (354,)
#
# x_test의 크기:  (152, 13)
# y_test의 크기:  (152,)
# <class 'pandas.core.series.Series'>

# %% [markdown]
# #### -Scailing

# %%
#학습 데이터 Scaling
scaler = StandardScaler()
scaler.fit(x_train)
x_train_scale = scaler.transform(x_train) # x_train_scale은 numpy ndarray 


#테스트 데이터 Scaling
x_test_scale = scaler.transform(x_test) # x_test_scale은 numpy ndarray 


# Array-->Tensor
x_train_tensor = torch.FloatTensor(x_train_scale)
y_train_tensor = torch.FloatTensor(y_train.values) #y_train은 판다스 Series이므로 values를 사용해서 numpy ndarray로 가져오기

x_test_tensor = torch.FloatTensor(x_test_scale)
y_test_tensor = torch.FloatTensor(y_test.values)

# %% [markdown]
# ##### -Batchfy

# %%
#학습 데이터 배치화 시키기 
train_data = data_utils.TensorDataset(x_train_tensor, y_train_tensor)

dataloader = data_utils.DataLoader(train_data, batch_size=100, shuffle=True , drop_last=True)


#배치화된 데이터 확인
for batch_idx, datas in enumerate(dataloader):
    print(batch_idx)
    print(datas[0].shape)  # x_train 
    print(datas[1].shape) # y_train
# Out:
# 0
# torch.Size([100, 13])
# torch.Size([100])
# 1
# torch.Size([100, 13])
# torch.Size([100])
# 2
# torch.Size([100, 13])
# torch.Size([100])

# %%
dataloader

# %% [markdown]
# ### 2) Model

# %%
# Modeling
class MLP_model(torch.nn.Module):
        def __init__(self, input_size, hidden_size, hidden_2_size ,output_size):
            super(MLP_model, self).__init__()
            self.input_size = input_size
            self.hidden_size = hidden_size
            self.hidden_2_size = hidden_2_size
            self.output_size = output_size
            
            
            self.fc1 = torch.nn.Linear(self.input_size, self.hidden_size)
            self.fc2 = torch.nn.Linear(self.hidden_size, self.hidden_2_size)
            self.fc3 = torch.nn.Linear(self.hidden_2_size, self.output_size)
            self.relu = torch.nn.ReLU()
            self.sig = torch.nn.Sigmoid()
            
        def forward(self, x):
            fc1 = self.fc1(x)
            ac1 = self.relu(fc1)
            fc2 = self.fc2(ac1)
            ac2 = self.relu(fc2)
            fc3 = self.fc3(ac2)
            
            
            return fc3

# %%
#Parameter 정의
input_dim = 13
output_dim = 1
hidden_dim = 32 # 보통 2의 배수
hidden_2_dim = 16
learning_rate = 0.005
n_epochs = 300

# %%
#model 생성
model = MLP_model(input_size = input_dim, hidden_size = hidden_dim, hidden_2_size=hidden_2_dim, output_size = output_dim)

# %%
#손실함수 생성
criterion = torch.nn.MSELoss()
#Optimizer 생성
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### 3) Training

# %%
# Training the model
train_loss = []
test_loss = []

for epoch in range(n_epochs+1):
    
    #Batch 학습
    for idx, (x_batch, y_batch) in enumerate(dataloader):
        # gradient 초기화
        optimizer.zero_grad()
        
        y_pred = model(x_batch)
        y_pred = y_pred.reshape(-1)
        loss_train = criterion(y_pred, y_batch)
        loss_train.backward()
        optimizer.step()
        
        #Validation
        y_test_pred = model(x_test_tensor)
        y_test_pred = y_test_pred.reshape(-1)
        loss_test = criterion(y_test_pred, y_test_tensor)

    train_loss.append(loss_train.item())
    test_loss.append(loss_test.item())
    print("epoch:{}, Loss_train:{:.2f}, Loss_test:{:.2f}".format( epoch, train_loss[-1], test_loss[-1]))
# Out:
# epoch:0, Loss_train:645.69, Loss_test:536.32
# epoch:1, Loss_train:392.70, Loss_test:239.97
# epoch:2, Loss_train:47.10, Loss_test:34.17
# epoch:3, Loss_train:54.08, Loss_test:56.71
# epoch:4, Loss_train:66.07, Loss_test:21.85
# epoch:5, Loss_train:45.15, Loss_test:79.84
# epoch:6, Loss_train:31.55, Loss_test:18.16
# epoch:7, Loss_train:28.59, Loss_test:37.60
# epoch:8, Loss_train:54.78, Loss_test:39.36
# epoch:9, Loss_train:38.36, Loss_test:51.21
# epoch:10, Loss_train:41.28, Loss_test:42.10
# epoch:11, Loss_train:38.57, Loss_test:41.79
# epoch:12, Loss_train:45.09, Loss_test:22.99
# epoch:13, Loss_train:16.14, Loss_test:25.17
# epoch:14, Loss_train:15.80, Loss_test:15.79
# epoch:15, Loss_train:15.34, Loss_test:19.38
# epoch:16, Loss_train:22.53, Loss_test:17.91
# epoch:17, Loss_train:12.78, Loss_test:17.38
# epoch:18, Loss_train:10.61, Loss_test:14.08
# epoch:19, Loss_train:16.40, Loss_test:21.38
# epoch:20, Loss_train:20.69, Loss_test:16.14
# epoch:21, Loss_train:9.11, Loss_test:12.62
# epoch:22, Loss_train:17.02, Loss_test:14.19
# epoch:23, Loss_train:12.90, Loss_test:16.41
# epoch:24, Loss_train:31.72, Loss_test:16.85
# epoch:25, Loss_train:23.41, Loss_test:23.20
# epoch:26, Loss_train:16.66, Loss_test:25.23
# epoch:27, Loss_train:14.26, Loss_test:18.46
# epoch:28, Loss_train:9.12, Loss_test:12.33
# epoch:29, Loss_train:15.56, Loss_test:15.13
# epoch:30, Loss_train:12.94, Loss_test:13.92
# epoch:31, Loss_train:11.26, Loss_test:11.84
# epoch:32, Loss_train:17.52, Loss_test:11.77
# epoch:33, Loss_train:11.88, Loss_test:18.50
# epoch:34, Loss_train:10.11, Loss_test:11.91
# epoch:35, Loss_train:11.83, Loss_test:13.75
# epoch:36, Loss_train:7.33, Loss_test:12.01
# epoch:37, Loss_train:8.93, Loss_test:11.80
# epoch:38, Loss_train:8.13, Loss_test:11.31
# epoch:39, Loss_train:13.98, Loss_test:13.54
# epoch:40, Loss_train:10.82, Loss_test:11.30
# epoch:41, Loss_train:10.28, Loss_test:12.23
# epoch:42, Loss_train:14.84, Loss_test:15.10
# epoch:43, Loss_train:12.76, Loss_test:12.79
# epoch:44, Loss_train:10.14, Loss_test:11.87
# epoch:45, Loss_train:10.51, Loss_test:13.59
# epoch:46, Loss_train:24.82, Loss_test:39.12
# epoch:47, Loss_train:20.14, Loss_test:14.11
# epoch:48, Loss_train:12.90, Loss_test:11.09
# epoch:49, Loss_train:8.29, Loss_test:11.78
# epoch:50, Loss_train:14.15, Loss_test:12.08
# epoch:51, Loss_train:12.46, Loss_test:11.91
# epoch:52, Loss_train:12.51, Loss_test:12.18
# epoch:53, Loss_train:12.63, Loss_test:11.57
# epoch:54, Loss_train:21.81, Loss_test:38.19
# epoch:55, Loss_train:22.02, Loss_test:16.33
# epoch:56, Loss_train:14.97, Loss_test:21.97
# epoch:57, Loss_train:26.06, Loss_test:21.54
# epoch:58, Loss_train:24.79, Loss_test:22.42
# epoch:59, Loss_train:22.61, Loss_test:20.62
# epoch:60, Loss_train:14.03, Loss_test:25.55
# epoch:61, Loss_train:12.14, Loss_test:12.84
# epoch:62, Loss_train:10.36, Loss_test:14.28
# epoch:63, Loss_train:9.99, Loss_test:13.10
# epoch:64, Loss_train:10.07, Loss_test:13.98
# epoch:65, Loss_train:7.87, Loss_test:11.22
# epoch:66, Loss_train:10.53, Loss_test:11.77
# epoch:67, Loss_train:14.36, Loss_test:13.54
# epoch:68, Loss_train:7.77, Loss_test:11.54
# epoch:69, Loss_train:7.18, Loss_test:10.87
# epoch:70, Loss_train:6.38, Loss_test:11.22
# epoch:71, Loss_train:13.87, Loss_test:11.96
# epoch:72, Loss_train:10.41, Loss_test:11.66
# epoch:73, Loss_train:14.09, Loss_test:14.19
# epoch:74, Loss_train:9.87, Loss_test:10.91
# epoch:75, Loss_train:7.15, Loss_test:10.93
# epoch:76, Loss_train:8.20, Loss_test:14.97
# epoch:77, Loss_train:9.18, Loss_test:12.14
# epoch:78, Loss_train:13.50, Loss_test:16.47
# epoch:79, Loss_train:28.62, Loss_test:28.35
# epoch:80, Loss_train:18.84, Loss_test:29.32
# epoch:81, Loss_train:12.72, Loss_test:15.08
# epoch:82, Loss_train:12.07, Loss_test:11.55
# epoch:83, Loss_train:13.82, Loss_test:13.78
# epoch:84, Loss_train:6.03, Loss_test:10.86
# epoch:85, Loss_train:12.28, Loss_test:16.32
# epoch:86, Loss_train:15.11, Loss_test:18.04
# epoch:87, Loss_train:15.07, Loss_test:16.11
# epoch:88, Loss_train:13.62, Loss_test:28.10
# epoch:89, Loss_train:7.94, Loss_test:12.71
# epoch:90, Loss_train:14.40, Loss_test:14.39
# epoch:91, Loss_train:9.80, Loss_test:13.58
# epoch:92, Loss_train:11.47, Loss_test:12.39
# epoch:93, Loss_train:6.01, Loss_test:11.52
# epoch:94, Loss_train:15.18, Loss_test:11.23
# epoch:95, Loss_train:10.01, Loss_test:12.54
# epoch:96, Loss_train:8.39, Loss_test:11.58
# epoch:97, Loss_train:8.13, Loss_test:10.99
# epoch:98, Loss_train:6.91, Loss_test:13.35
# epoch:99, Loss_train:8.66, Loss_test:13.61
# epoch:100, Loss_train:9.73, Loss_test:15.46
# epoch:101, Loss_train:10.96, Loss_test:14.19
# epoch:102, Loss_train:11.19, Loss_test:11.84
# epoch:103, Loss_train:11.94, Loss_test:14.43
# epoch:104, Loss_train:9.40, Loss_test:15.58
# epoch:105, Loss_train:9.08, Loss_test:16.46
# epoch:106, Loss_train:11.88, Loss_test:14.62
# epoch:107, Loss_train:13.36, Loss_test:12.87
# epoch:108, Loss_train:9.47, Loss_test:12.16
# epoch:109, Loss_train:7.95, Loss_test:12.16
# epoch:110, Loss_train:10.55, Loss_test:10.76
# epoch:111, Loss_train:6.33, Loss_test:11.17
# epoch:112, Loss_train:10.76, Loss_test:11.43
# epoch:113, Loss_train:11.28, Loss_test:12.97
# epoch:114, Loss_train:9.99, Loss_test:11.20
# epoch:115, Loss_train:8.46, Loss_test:10.87
# epoch:116, Loss_train:5.75, Loss_test:10.28
# epoch:117, Loss_train:12.27, Loss_test:13.75
# epoch:118, Loss_train:11.05, Loss_test:11.08
# epoch:119, Loss_train:8.76, Loss_test:11.16
# epoch:120, Loss_train:8.10, Loss_test:11.90
# epoch:121, Loss_train:10.15, Loss_test:11.62
# epoch:122, Loss_train:7.75, Loss_test:10.55
# epoch:123, Loss_train:7.60, Loss_test:13.13
# epoch:124, Loss_train:8.16, Loss_test:12.11
# epoch:125, Loss_train:10.10, Loss_test:11.98
# epoch:126, Loss_train:11.12, Loss_test:10.95
# epoch:127, Loss_train:8.03, Loss_test:10.74
# epoch:128, Loss_train:8.69, Loss_test:11.75
# epoch:129, Loss_train:7.95, Loss_test:10.40
# epoch:130, Loss_train:6.32, Loss_test:11.15
# epoch:131, Loss_train:11.07, Loss_test:11.65
# epoch:132, Loss_train:10.25, Loss_test:17.93
# epoch:133, Loss_train:9.38, Loss_test:15.85
# epoch:134, Loss_train:7.02, Loss_test:11.17
# epoch:135, Loss_train:8.73, Loss_test:11.73
# epoch:136, Loss_train:12.06, Loss_test:17.29
# epoch:137, Loss_train:14.39, Loss_test:17.37
# epoch:138, Loss_train:7.23, Loss_test:10.93
# epoch:139, Loss_train:6.49, Loss_test:11.53
# epoch:140, Loss_train:11.76, Loss_test:10.27
# epoch:141, Loss_train:9.79, Loss_test:10.65
# epoch:142, Loss_train:5.51, Loss_test:13.02
# epoch:143, Loss_train:6.60, Loss_test:10.31
# epoch:144, Loss_train:4.98, Loss_test:10.41
# epoch:145, Loss_train:6.48, Loss_test:11.48
# epoch:146, Loss_train:13.23, Loss_test:24.08
# epoch:147, Loss_train:10.36, Loss_test:15.80
# epoch:148, Loss_train:11.33, Loss_test:11.29
# epoch:149, Loss_train:7.65, Loss_test:11.42
# epoch:150, Loss_train:6.92, Loss_test:10.97
# epoch:151, Loss_train:8.10, Loss_test:12.99
# epoch:152, Loss_train:8.31, Loss_test:11.53
# epoch:153, Loss_train:11.85, Loss_test:15.28
# epoch:154, Loss_train:7.66, Loss_test:11.20
# epoch:155, Loss_train:8.00, Loss_test:14.26
# epoch:156, Loss_train:10.83, Loss_test:13.32
# epoch:157, Loss_train:9.79, Loss_test:12.10
# epoch:158, Loss_train:8.30, Loss_test:11.49
# epoch:159, Loss_train:7.43, Loss_test:11.52
# epoch:160, Loss_train:5.89, Loss_test:10.37
# epoch:161, Loss_train:8.86, Loss_test:13.03
# epoch:162, Loss_train:7.13, Loss_test:10.37
# epoch:163, Loss_train:5.50, Loss_test:10.88
# epoch:164, Loss_train:9.45, Loss_test:13.23
# epoch:165, Loss_train:10.41, Loss_test:14.07
# epoch:166, Loss_train:10.72, Loss_test:12.03
# epoch:167, Loss_train:10.68, Loss_test:10.39
# epoch:168, Loss_train:9.69, Loss_test:11.09
# epoch:169, Loss_train:9.45, Loss_test:11.38
# epoch:170, Loss_train:6.51, Loss_test:14.00
# epoch:171, Loss_train:5.66, Loss_test:13.14
# epoch:172, Loss_train:10.33, Loss_test:10.80
# epoch:173, Loss_train:5.47, Loss_test:11.59
# epoch:174, Loss_train:11.84, Loss_test:11.39
# epoch:175, Loss_train:11.71, Loss_test:15.54
# epoch:176, Loss_train:9.15, Loss_test:11.72
# epoch:177, Loss_train:7.18, Loss_test:11.07
# epoch:178, Loss_train:5.98, Loss_test:10.04
# epoch:179, Loss_train:7.75, Loss_test:10.94
# epoch:180, Loss_train:7.26, Loss_test:10.31
# epoch:181, Loss_train:5.48, Loss_test:10.50
# epoch:182, Loss_train:4.58, Loss_test:10.33
# epoch:183, Loss_train:7.97, Loss_test:10.86
# epoch:184, Loss_train:6.94, Loss_test:11.33
# epoch:185, Loss_train:7.09, Loss_test:10.39
# epoch:186, Loss_train:3.78, Loss_test:10.52
# epoch:187, Loss_train:17.12, Loss_test:18.58
# epoch:188, Loss_train:8.62, Loss_test:10.56
# epoch:189, Loss_train:4.95, Loss_test:10.41
# epoch:190, Loss_train:5.13, Loss_test:10.31
# epoch:191, Loss_train:8.07, Loss_test:12.71
# epoch:192, Loss_train:7.25, Loss_test:13.22
# epoch:193, Loss_train:8.18, Loss_test:12.02
# epoch:194, Loss_train:5.25, Loss_test:10.42
# epoch:195, Loss_train:7.46, Loss_test:11.04
# epoch:196, Loss_train:4.78, Loss_test:10.54
# epoch:197, Loss_train:6.07, Loss_test:10.81
# epoch:198, Loss_train:7.23, Loss_test:11.58
# epoch:199, Loss_train:8.94, Loss_test:13.98
# epoch:200, Loss_train:7.67, Loss_test:11.79
# epoch:201, Loss_train:5.75, Loss_test:10.74
# epoch:202, Loss_train:9.75, Loss_test:14.59
# epoch:203, Loss_train:5.37, Loss_test:10.49
# epoch:204, Loss_train:7.44, Loss_test:11.42
# epoch:205, Loss_train:7.05, Loss_test:10.40
# epoch:206, Loss_train:5.98, Loss_test:10.19
# epoch:207, Loss_train:5.27, Loss_test:11.17
# epoch:208, Loss_train:7.46, Loss_test:12.52
# epoch:209, Loss_train:7.66, Loss_test:10.40
# epoch:210, Loss_train:5.24, Loss_test:10.38
# epoch:211, Loss_train:5.55, Loss_test:10.32
# epoch:212, Loss_train:7.59, Loss_test:13.24
# epoch:213, Loss_train:14.84, Loss_test:12.63
# epoch:214, Loss_train:7.37, Loss_test:10.58
# epoch:215, Loss_train:5.94, Loss_test:10.84
# epoch:216, Loss_train:5.32, Loss_test:11.00
# epoch:217, Loss_train:5.53, Loss_test:10.34
# epoch:218, Loss_train:8.01, Loss_test:10.36
# epoch:219, Loss_train:6.47, Loss_test:11.62
# epoch:220, Loss_train:5.09, Loss_test:10.35
# epoch:221, Loss_train:5.09, Loss_test:11.01
# epoch:222, Loss_train:7.41, Loss_test:12.83
# epoch:223, Loss_train:18.05, Loss_test:15.23
# epoch:224, Loss_train:15.77, Loss_test:17.07
# epoch:225, Loss_train:18.73, Loss_test:24.69
# epoch:226, Loss_train:9.02, Loss_test:14.15
# epoch:227, Loss_train:6.26, Loss_test:10.80
# epoch:228, Loss_train:6.16, Loss_test:11.24
# epoch:229, Loss_train:6.94, Loss_test:11.36
# epoch:230, Loss_train:6.27, Loss_test:11.66
# epoch:231, Loss_train:6.56, Loss_test:11.18
# epoch:232, Loss_train:8.42, Loss_test:13.58
# epoch:233, Loss_train:8.82, Loss_test:11.73
# epoch:234, Loss_train:6.23, Loss_test:10.61
# epoch:235, Loss_train:8.32, Loss_test:10.83
# epoch:236, Loss_train:4.85, Loss_test:10.41
# epoch:237, Loss_train:9.13, Loss_test:10.58
# epoch:238, Loss_train:7.97, Loss_test:10.64
# epoch:239, Loss_train:5.20, Loss_test:10.39
# epoch:240, Loss_train:7.79, Loss_test:11.73
# epoch:241, Loss_train:4.85, Loss_test:10.50
# epoch:242, Loss_train:7.52, Loss_test:11.63
# epoch:243, Loss_train:11.87, Loss_test:15.50
# epoch:244, Loss_train:7.48, Loss_test:12.98
# epoch:245, Loss_train:13.95, Loss_test:19.01
# epoch:246, Loss_train:8.85, Loss_test:17.15
# epoch:247, Loss_train:9.12, Loss_test:14.69
# epoch:248, Loss_train:9.89, Loss_test:13.15
# epoch:249, Loss_train:13.19, Loss_test:19.12
# epoch:250, Loss_train:9.97, Loss_test:14.52
# epoch:251, Loss_train:7.24, Loss_test:12.33
# epoch:252, Loss_train:4.98, Loss_test:11.33
# epoch:253, Loss_train:8.38, Loss_test:12.97
# epoch:254, Loss_train:5.20, Loss_test:10.20
# epoch:255, Loss_train:7.23, Loss_test:13.42
# epoch:256, Loss_train:6.36, Loss_test:13.63
# epoch:257, Loss_train:7.97, Loss_test:12.65
# epoch:258, Loss_train:7.30, Loss_test:12.85
# epoch:259, Loss_train:5.18, Loss_test:10.55
# epoch:260, Loss_train:8.36, Loss_test:12.43
# epoch:261, Loss_train:5.71, Loss_test:10.42
# epoch:262, Loss_train:7.60, Loss_test:10.80
# epoch:263, Loss_train:6.55, Loss_test:10.00
# epoch:264, Loss_train:5.98, Loss_test:11.24
# epoch:265, Loss_train:6.40, Loss_test:11.49
# epoch:266, Loss_train:9.13, Loss_test:12.88
# epoch:267, Loss_train:7.20, Loss_test:10.40
# epoch:268, Loss_train:6.48, Loss_test:11.41
# epoch:269, Loss_train:4.48, Loss_test:10.25
# epoch:270, Loss_train:4.80, Loss_test:10.74
# epoch:271, Loss_train:12.32, Loss_test:20.01
# epoch:272, Loss_train:5.53, Loss_test:10.43
# epoch:273, Loss_train:6.92, Loss_test:10.30
# epoch:274, Loss_train:11.14, Loss_test:15.86
# epoch:275, Loss_train:6.73, Loss_test:10.18
# epoch:276, Loss_train:5.03, Loss_test:10.84
# epoch:277, Loss_train:7.64, Loss_test:10.88
# epoch:278, Loss_train:3.98, Loss_test:10.13
# epoch:279, Loss_train:9.19, Loss_test:13.18
# epoch:280, Loss_train:5.47, Loss_test:10.70
# epoch:281, Loss_train:5.13, Loss_test:11.58
# epoch:282, Loss_train:6.69, Loss_test:13.99
# epoch:283, Loss_train:10.09, Loss_test:11.06
# epoch:284, Loss_train:8.30, Loss_test:13.76
# epoch:285, Loss_train:9.82, Loss_test:15.69
# epoch:286, Loss_train:11.87, Loss_test:16.25
# epoch:287, Loss_train:6.17, Loss_test:12.63
# epoch:288, Loss_train:4.81, Loss_test:11.69
# epoch:289, Loss_train:8.39, Loss_test:11.08
# epoch:290, Loss_train:5.62, Loss_test:10.36
# epoch:291, Loss_train:5.76, Loss_test:10.59
# epoch:292, Loss_train:7.42, Loss_test:11.77
# epoch:293, Loss_train:4.14, Loss_test:10.60
# epoch:294, Loss_train:4.43, Loss_test:10.39
# epoch:295, Loss_train:8.02, Loss_test:11.46
# epoch:296, Loss_train:7.02, Loss_test:14.01
# epoch:297, Loss_train:8.92, Loss_test:15.79
# epoch:298, Loss_train:8.01, Loss_test:10.96
# epoch:299, Loss_train:7.09, Loss_test:11.47
# epoch:300, Loss_train:8.65, Loss_test:11.44

# %%
# Loss 값 plot
plt.figure()
plt.plot(train_loss, label='train')
plt.plot(test_loss, label='test')
plt.title('Model loss')
plt.legend(loc= 'upper right')
plt.show()

# %% [markdown]
# ### <Scaling>
