# %%
# !python3 -m pip install -U scikit-image

# %%
import skimage

# %%
 from skimage import color, data
img = color.rgb2gray(data.coffee())
img += 0.5 * img.std() * np.random.randn(*img.shape)
img_plot = plt.imshow(img, cmap='gray')
plt.show()

# %%
denoised_img = skimage.restoration.denoise_tv_chambolle(img, weight=60)

# %%
imgplot = plt.imshow(denoised_img, cmap='gray')
plt.show()
